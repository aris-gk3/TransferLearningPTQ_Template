# %% [markdown]
# ### Random Image Inspection

# %%
from PIL import Image
import numpy as np

# Load the image
img_path = r''
img = Image.open(f"{img_path}")

# Show the image
img.show()

# Print image metadata
print("Format:", img.format)
print("Mode:", img.mode)         # e.g., 'RGB', 'I;16', 'L', 'CMYK'
print("Size:", img.size)         # (width, height)

# Convert to NumPy array
img_np = np.array(img)

# Examine array shape and data type
print("Array shape:", img_np.shape)
print("Data type:", img_np.dtype)
print("Min/Max pixel values:", img_np.min(), img_np.max())

# %% [markdown]
# ## Return Counts of each format

# %%
import os
from collections import defaultdict

def count_file_types(path):
    file_type_counts = defaultdict(int)
    
    for root, dirs, files in os.walk(path):
        for file in files:
            _, ext = os.path.splitext(file)
            ext = ext.lower() if ext else 'NO_EXTENSION'
            file_type_counts[ext] += 1
    
    return dict(file_type_counts)

# Example usage

path = r"C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy"
file_types = count_file_types(path)

for ext, count in sorted(file_types.items(), key=lambda x: x[1], reverse=True):
    print(f"{ext}: {count}")
# Out:
# .jpg: 7385

# %%
import os

def find_mat_files(folder_path):
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith('.mat'):
                print(os.path.join(root, file))

# Example usage:
folder = r"C:\Users\arisi\Downloads\archive\OxfordPetsRemoved"
find_mat_files(folder)
# Out:
# C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Abyssinian\Abyssinian_100.mat
# C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Abyssinian\Abyssinian_101.mat
# C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Abyssinian\Abyssinian_102.mat

# %% [markdown]
# ### Move all files of specific format(s)

# %%
import os
import shutil

def copy_files_by_type(src_dir, dst_dir, extensions_to_copy):
    """
    Copy files with specified extensions from src_dir to dst_dir, preserving folder structure.

    Args:
        src_dir (str): Source directory to search files in.
        dst_dir (str): Destination directory to copy files to.
        extensions_to_copy (set): Set of lowercase file extensions to copy, e.g., {'.jpg', '.txt'}
    """
    for root, dirs, files in os.walk(src_dir):
        for file in files:
            _, ext = os.path.splitext(file)
            if ext.lower() in extensions_to_copy:
                # Get relative path from the source root
                rel_path = os.path.relpath(root, src_dir)
                # Build target directory path
                target_dir = os.path.join(dst_dir, rel_path)
                os.makedirs(target_dir, exist_ok=True)
                
                # Full source and destination file paths
                src_file_path = os.path.join(root, file)
                dst_file_path = os.path.join(target_dir, file)

                shutil.copy2(src_file_path, dst_file_path)
                print(f"Copied: {src_file_path} -> {dst_file_path}")

# Example usage

src_directory = r"C:\Users\arisi\Downloads\archive\OxfordPetsRemoved"
dst_directory = r"C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy"
file_types = {".jpg", ".png", ".txt"}  # specify extensions to copy

copy_files_by_type(src_directory, dst_directory, file_types)
# Out:
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Abyssinian\Abyssinian_105.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Abyssinian\Abyssinian_105.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Abyssinian\Abyssinian_136.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Abyssinian\Abyssinian_136.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Abyssinian\Abyssinian_143.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Abyssinian\Abyssinian_143.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Abyssinian\Abyssinian_149.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Abyssinian\Abyssinian_149.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Abyssinian\Abyssinian_15.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Abyssinian\Abyssinian_15.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Abyssinian\Abyssinian_164.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Abyssinian\Abyssinian_164.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Abyssinian\Abyssinian_170.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Abyssinian\Abyssinian_170.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Abyssinian\Abyssinian_178.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Abyssinian\Abyssinian_178.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Abyssinian\Abyssinian_226.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Abyssinian\Abyssinian_226.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Abyssinian\Abyssinian_228.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Abyssinian\Abyssinian_228.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Abyssinian\Abyssinian_230.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Abyssinian\Abyssinian_230.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Abyssinian\Abyssinian_3.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Abyssinian\Abyssinian_3.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Abyssinian\Abyssinian_31.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Abyssinian\Abyssinian_31.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Abyssinian\Abyssinian_37.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Abyssinian\Abyssinian_37.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Abyssinian\Abyssinian_57.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Abyssinian\Abyssinian_57.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Abyssinian\Abyssinian_68.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Abyssinian\Abyssinian_68.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Abyssinian\Abyssinian_73.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Abyssinian\Abyssinian_73.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Abyssinian\Abyssinian_95.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Abyssinian\Abyssinian_95.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Abyssinian\Abyssinian_98.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Abyssinian\Abyssinian_98.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Bulldog\american_bulldog_10.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Bulldog\american_bulldog_10.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Bulldog\american_bulldog_107.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Bulldog\american_bulldog_107.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Bulldog\american_bulldog_128.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Bulldog\american_bulldog_128.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Bulldog\american_bulldog_133.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Bulldog\american_bulldog_133.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Bulldog\american_bulldog_135.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Bulldog\american_bulldog_135.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Bulldog\american_bulldog_177.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Bulldog\american_bulldog_177.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Bulldog\american_bulldog_18.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Bulldog\american_bulldog_18.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Bulldog\american_bulldog_199.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Bulldog\american_bulldog_199.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Bulldog\american_bulldog_205.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Bulldog\american_bulldog_205.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Bulldog\american_bulldog_212.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Bulldog\american_bulldog_212.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Bulldog\american_bulldog_22.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Bulldog\american_bulldog_22.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Bulldog\american_bulldog_43.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Bulldog\american_bulldog_43.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Bulldog\american_bulldog_56.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Bulldog\american_bulldog_56.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Bulldog\american_bulldog_58.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Bulldog\american_bulldog_58.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Bulldog\american_bulldog_6.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Bulldog\american_bulldog_6.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Bulldog\american_bulldog_62.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Bulldog\american_bulldog_62.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Bulldog\american_bulldog_67.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Bulldog\american_bulldog_67.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Bulldog\american_bulldog_77.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Bulldog\american_bulldog_77.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Bulldog\american_bulldog_89.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Bulldog\american_bulldog_89.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Bulldog\american_bulldog_95.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Bulldog\american_bulldog_95.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Pitbull\american_pit_bull_terrier_109.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Pitbull\american_pit_bull_terrier_109.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Pitbull\american_pit_bull_terrier_112.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Pitbull\american_pit_bull_terrier_112.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Pitbull\american_pit_bull_terrier_134.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Pitbull\american_pit_bull_terrier_134.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Pitbull\american_pit_bull_terrier_137.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Pitbull\american_pit_bull_terrier_137.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Pitbull\american_pit_bull_terrier_147.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Pitbull\american_pit_bull_terrier_147.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Pitbull\american_pit_bull_terrier_15.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Pitbull\american_pit_bull_terrier_15.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Pitbull\american_pit_bull_terrier_157.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Pitbull\american_pit_bull_terrier_157.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Pitbull\american_pit_bull_terrier_165.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Pitbull\american_pit_bull_terrier_165.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Pitbull\american_pit_bull_terrier_184.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Pitbull\american_pit_bull_terrier_184.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\American_Pitbull\american_pit_bull_terrier_194.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\American_Pitbull\american_pit_bull_terrier
jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Egyptian_Mau\Egyptian_Mau_22.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Egyptian_Mau\Egyptian_Mau_22.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Egyptian_Mau\Egyptian_Mau_58.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Egyptian_Mau\Egyptian_Mau_58.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Egyptian_Mau\Egyptian_Mau_70.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Egyptian_Mau\Egyptian_Mau_70.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Egyptian_Mau\Egyptian_Mau_76.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Egyptian_Mau\Egyptian_Mau_76.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Egyptian_Mau\Egyptian_Mau_80.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Egyptian_Mau\Egyptian_Mau_80.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\Egyptian_Mau\Egyptian_Mau_98.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\Egyptian_Mau\Egyptian_Mau_98.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\English_Cocker\english_cocker_spaniel_1.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\English_Cocker\english_cocker_spaniel_1.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\English_Cocker\english_cocker_spaniel_115.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\English_Cocker\english_cocker_spaniel_115.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\English_Cocker\english_cocker_spaniel_134.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\English_Cocker\english_cocker_spaniel_134.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\English_Cocker\english_cocker_spaniel_143.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\English_Cocker\english_cocker_spaniel_143.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\English_Cocker\english_cocker_spaniel_145.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\English_Cocker\english_cocker_spaniel_145.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\English_Cocker\english_cocker_spaniel_165.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\English_Cocker\english_cocker_spaniel_165.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\English_Cocker\english_cocker_spaniel_169.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\English_Cocker\english_cocker_spaniel_169.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\English_Cocker\english_cocker_spaniel_176.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\English_Cocker\english_cocker_spaniel_176.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\English_Cocker\english_cocker_spaniel_177.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\English_Cocker\english_cocker_spaniel_177.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\English_Cocker\english_cocker_spaniel_194.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\English_Cocker\english_cocker_spaniel_194.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\English_Cocker\english_cocker_spaniel_197.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\English_Cocker\english_cocker_spaniel_197.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\English_Cocker\english_cocker_spaniel_198.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\English_Cocker\english_cocker_spaniel_198.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\English_Cocker\english_cocker_spaniel_3.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\English_Cocker\english_cocker_spaniel_3.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Test\English_Cocker\english_cocker_spaniel_32.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Test\English_Cocker\english_cocker_spaniel_32.jpg
# ...
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_3.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_3.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_30.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_30.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_31.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_31.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_32.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_32.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_33.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_33.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_34.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_34.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_35.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_35.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_36.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_36.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_37.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_37.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_38.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_38.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_39.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_39.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_4.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_4.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_40.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_40.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_42.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_42.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_43.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_43.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_44.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_44.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_45.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_45.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_46.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_46.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_47.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_47.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_48.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_48.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_5.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_5.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_50.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_50.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_51.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_51.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_52.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_52.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_53.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_53.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_54.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_54.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_55.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_55.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_56.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_56.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_58.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_58.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_59.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_59.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_6.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_6.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_61.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_61.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_62.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_62.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_63.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_63.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_64.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_64.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_65.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_65.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_66.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_66.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_68.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_68.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_69.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_69.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_7.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_7.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_70.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_70.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_71.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_71.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_72.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_72.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_73.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_73.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_74.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_74.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_75.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_75.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_76.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_76.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_77.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_77.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_78.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_78.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_79.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_79.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_8.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_8.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_80.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_80.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_82.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_82.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_83.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_83.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_84.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_84.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_85.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_85.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_86.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_86.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_87.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_87.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_88.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_88.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_89.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_89.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_9.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_9.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_90.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_90.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_91.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_91.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_92.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_92.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_93.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_93.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_94.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_94.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_95.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_95.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_96.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_96.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_97.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_97.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_98.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_98.jpg
# Copied: C:\Users\arisi\Downloads\archive\OxfordPetsRemoved\Train_val\Yorkshire_Terrier\yorkshire_terrier_99.jpg -> C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Yorkshire_Terrier\yorkshire_terrier_99.jpg

# %% [markdown]
# ### Verify File  Formats and Corruption

# %%
from PIL import Image, UnidentifiedImageError
import os

folder_path = r''

for filename in os.listdir(folder_path):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif', '.tiff', '.webp')):
        filepath = os.path.join(folder_path, filename)
        try:
            with Image.open(filepath) as img:
                img.verify()  # Detect corrupted image
                format = img.format  # Get image format (e.g., JPEG, PNG)
                print(f"{filename} is a valid {format} file.")
        except UnidentifiedImageError:
            print(f"{filename} is NOT a valid image or is corrupted!")
        except Exception as e:
            print(f"{filename} failed with error: {e}")

# %%
# Verifies image corruption
import os
from PIL import Image

dataset_dir = r""
for root, dirs, files in os.walk(dataset_dir):
    for file in files:
        file_path = os.path.join(root, file)
        try:
            img = Image.open(file_path)
            img.verify()  # Verify the image is valid
        except Exception as e:
            print(f"Corrupted or invalid image: {file_path} ({e})")

# %% [markdown]
# ### Convert all files recursively to PNG

# %%
import os
from PIL import Image

def convert_tif_to_png_recursive(input_root, output_root):
    for dirpath, _, filenames in os.walk(input_root):
        for file in filenames:
            if file.lower().endswith((".tif", ".tiff")):
                input_path = os.path.join(dirpath, file)
                
                # Build relative path for output
                rel_dir = os.path.relpath(dirpath, input_root)
                output_dir = os.path.join(output_root, rel_dir)
                os.makedirs(output_dir, exist_ok=True)
                
                # Load and convert image
                try:
                    img = Image.open(input_path)
                    
                    # Convert to RGB if not already
                    if img.mode != "RGB":
                        img = img.convert("RGB")
                    
                    # Save as PNG
                    output_filename = os.path.splitext(file)[0] + ".png"
                    output_path = os.path.join(output_dir, output_filename)
                    img.save(output_path)
                    
                    print(f"Converted: {input_path} → {output_path}")
                except Exception as e:
                    print(f"Failed to convert {input_path}: {e}")


input_folder = r""
output_folder = r""
convert_tif_to_png_recursive(input_folder, output_folder)

# %% [markdown]
# ### Check for Image Dimensions

# %%
from PIL import Image
import os

# Path to your folder
folder_path = ''

# Dictionary to track dimensions
dimension_counts = {}

for filename in os.listdir(folder_path):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
        filepath = os.path.join(folder_path, filename)
        with Image.open(filepath) as img:
            dimensions = img.size  # (width, height)
            dimension_counts[dimensions] = dimension_counts.get(dimensions, 0) + 1

# Print summary
for dims, count in dimension_counts.items():
    print(f"Dimension {dims}: {count} image(s)")

# %%
target_size = (224, 224)
for filename in os.listdir(folder_path):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
        filepath = os.path.join(folder_path, filename)
        with Image.open(filepath) as img:
            if img.size != target_size:
                print(f"{filename} has size {img.size}")

# %% [markdown]
# ### Color Mode Check

# %%
from PIL import Image, UnidentifiedImageError
import os

folder_path = r"C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Abyssinian"

# Count modes
mode_counts = {}

for filename in os.listdir(folder_path):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif', '.tiff', '.webp')):
        filepath = os.path.join(folder_path, filename)
        try:
            with Image.open(filepath) as img:
                mode = img.mode  # e.g., 'RGB', 'L', 'CMYK', 'RGBA'
                mode_counts[mode] = mode_counts.get(mode, 0) + 1

                if mode != 'RGB':
                    print(f"⚠️ {filename} is in {mode} mode!")
        except UnidentifiedImageError:
            print(f"❌ {filename} is not a valid image or is corrupted.")

print("\n✅ Color Mode Summary:")
for mode, count in mode_counts.items():
    print(f"{mode}: {count} image(s)")
# Out:
# ⚠️ Abyssinian_5.jpg is in RGBA mode!
#
# ✅ Color Mode Summary:
# RGB: 179 image(s)
# RGBA: 1 image(s)

# %%
import os
from PIL import Image

def convert_rgba_to_rgb_recursive(folder_path, output_folder=None):
    """
    Recursively convert all RGBA images in folder_path to RGB.
    Saves images either overwriting original or to output_folder if provided.
    """
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            file_path = os.path.join(root, file)

            try:
                with Image.open(file_path) as img:
                    if img.mode == 'RGBA':
                        print(f"Converting {file_path} from RGBA to RGB")
                        rgb_img = img.convert('RGB')

                        # Determine save path
                        if output_folder:
                            # Preserve directory structure in output_folder
                            relative_path = os.path.relpath(root, folder_path)
                            save_dir = os.path.join(output_folder, relative_path)
                            os.makedirs(save_dir, exist_ok=True)
                            save_path = os.path.join(save_dir, file)
                        else:
                            # Overwrite original file
                            save_path = file_path

                        rgb_img.save(save_path)
            except Exception as e:
                print(f"Skipping {file_path}, error: {e}")

# Example usage:
input_folder = r"C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy"
output_folder = r"C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy2"

convert_rgba_to_rgb_recursive(input_folder, output_folder)
# Out:
# Converting C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Abyssinian\Abyssinian_5.jpg from RGBA to RGB
# Converting C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Egyptian_Mau\Egyptian_Mau_14.jpg from RGBA to RGB
# Converting C:\Users\arisi\Downloads\archive\OxfordPetsRemoved_copy\Train_val\Egyptian_Mau\Egyptian_Mau_186.jpg from RGBA to RGB

# %% [markdown]
# ### Convert other formats to RGB

# %%
import os
from PIL import Image

folder_path = ''
output_path = ''

os.makedirs(output_path, exist_ok=True)

for filename in os.listdir(folder_path):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif', '.tiff', '.webp')):
        filepath = os.path.join(folder_path, filename)
        with Image.open(filepath) as img:
            if img.mode != 'RGB':
                img = img.convert('RGB')
                print(f"Converted {filename} from {img.mode} to RGB")
            else:
                print(f"{filename} is already RGB")
            img.save(os.path.join(output_path, filename))
